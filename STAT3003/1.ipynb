# %%
data = [
    3632, 4097, 4258, 3760, 3731, 3144, 3612, 3761, 4158
]

# %%
y_mean = sum(data) / len(data)

variance = sum((x - y_mean) ** 2 for x in data) / (len(data) - 1)

# %%
41*41*(41-9)/41*variance/9
# Out:
# 16904346.567901235

# %%
tau = y_mean*41
tau
# Out:
# 155585.8888888889

# %% [markdown]
# N is the number of primary units in the population
# n is the number of primary units in the sample
# $M_i$ is the number of secondary units in the *i*th primary unit  $M = \sum_{i=1}^{N} M_i$ is the total number of secondary units in the population
# $Y_{ij}$ is the *j*th observation in the *i*th primary unit
# $Y_i = \sum_{j=1}^{M_i} Y_{ij}$ is the total of observations in the $i$th primary unit
